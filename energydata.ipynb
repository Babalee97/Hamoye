# %%
import pandas as pd

# %%
df = pd.read_csv('energydata_complete.csv')

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.isnull().any()
# Out:
# date           False
# Appliances     False
# lights         False
# T1             False
# RH_1           False
# T2             False
# RH_2           False
# T3             False
# RH_3           False
# T4             False
# RH_4           False
# T5             False
# RH_5           False
# T6             False
# RH_6           False
# T7             False
# RH_7           False
# T8             False
# RH_8           False
# T9             False
# RH_9           False
# T_out          False
# Press_mm_hg    False
# RH_out         False
# Windspeed      False
# Visibility     False
# Tdewpoint      False
# rv1            False
# rv2            False
# dtype: bool

# %%
df.duplicated(subset).any()
# Out:
# False

# %%
column_name = {'T1'   : 'kitchen_temp',
               'RH_1' : 'kitchen_humidity',
               'T2'   : 'living_room_temp',
               'RH_2' : 'living_room_humidity',
               'T3'   : 'laundry_temp',
               'RH_3' : 'laundry_room_humidity',
               'T4'   : 'office_room_temp',
               'RH_4' : 'office_room_humidity',
               'T5'   : 'bathroom_temp',
               'RH_5' : 'bathroom_humidity',
               'T6'   : 'outside_north_temp',
               'RH_6' : 'outside_north_humidity',
               'T7'   : 'ironing_room_temp',
               'RH_7' : 'ironing_room_humidity',
               'T8'   : 'teenager_room_temp',
               'RH_8' : 'teenager_room_humidity',
               'T9'   : 'parents_room_temp',
               'RH_9' : 'parents_room_humidity',
               'T_out': 'atmospheric_temp',
               'Pressure' : 'atmospheric_pressure',
               'RH_out'   : 'atmospheric_humidity', 
              }

# %%
df = df.rename(columns=column_name)

# %%
df.head()
# Out:
#                   date  Appliances  lights  kitchen_temp  kitchen_humidity  \
# 0  2016-01-11 17:00:00          60      30         19.89         47.596667
# 1  2016-01-11 17:10:00          60      30         19.89         46.693333
# 2  2016-01-11 17:20:00          50      30         19.89         46.300000
# 3  2016-01-11 17:30:00          50      40         19.89         46.066667
# 4  2016-01-11 17:40:00          60      40         19.89         46.333333
#
#    living_room_temp  living_room_humidity  laundry_temp  \
# 0              19.2             44.790000         19.79
# 1              19.2             44.722500         19.79
# 2              19.2             44.626667         19.79
# 3              19.2             44.590000         19.79
# 4              19.2             44.530000         19.79
#
#    laundry_room_humidity  office_room_temp  ...  parents_room_temp  \
# 0              44.730000         19.000000  ...          17.033333
# ...

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
correlation = df.corr()

# %%
fig = plt.figure(figsize=(12,8))
sns.heatmap(correlation, annot=True, linewidths=0.5, linecolor='blue', cbar=False,
           )
plt.show()

# %%
sample_data = df[['living_room_temp', 'outside_north_temp']]
sns.regplot(data=sample_data, x='living_room_temp', y='outside_north_temp')
# Out:
# <AxesSubplot:xlabel='living_room_temp', ylabel='outside_north_temp'>

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(sample_data[['living_room_temp']], sample_data['outside_north_temp'],
                                                    test_size=0.3, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
predicted_values = linear_model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 2)
# Out:
# 0.65

# %%
df = df.drop(['date', 'lights'], axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('Appliances', axis=1), df['Appliances'],
                                                            test_size=0.3, random_state=42)

# %%
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
predicted_values = linear_model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 2)
# Out:
# 0.05

# %%
import numpy as np
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 2)
# Out:
# 45.35

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.088

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 2)
# Out:
# 0.15

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.5)
ridge_reg.fit(x_train, y_train)

from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
def get_weights_df(model, feat, col_name):
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')
final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')

# %%
final_weights.sort_values(by='Linear_Model_Weight')
# Out:
#                   Features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 0     living_room_humidity            -0.456698     -0.401134     -0.000000
# 1         atmospheric_temp            -0.321860     -0.250765      0.000000
# 2         living_room_temp            -0.236178     -0.193880      0.000000
# 3        parents_room_temp            -0.189941     -0.188584     -0.000000
# 4   teenager_room_humidity            -0.157595     -0.156596     -0.000110
# 5     atmospheric_humidity            -0.077671     -0.050541     -0.049557
# 6    ironing_room_humidity            -0.044614     -0.046291     -0.000000
# 7    parents_room_humidity            -0.039800     -0.041701     -0.000000
# 8            bathroom_temp            -0.015657     -0.020727     -0.000000
# 9             kitchen_temp            -0.003281     -0.021549      0.000000
# 10                     rv2             0.000770      0.000743     -0.000000
# ...
